# %%
# !pip3 install ./dist/mlib-0.0.4-py3-none-any.whl --force-reinstall
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Processing ./dist/mlib-0.0.4-py3-none-any.whl
# Installing collected packages: mlib
#   Attempting uninstall: mlib
#     Found existing installation: mlib 0.0.4
#     Uninstalling mlib-0.0.4:
#       Successfully uninstalled mlib-0.0.4
# Successfully installed mlib-0.0.4

# %%
import pandas as pd
import numpy as np
from mlib.sl import LogisticRegression

# %%
training = pd.read_csv("DS/iris-data.csv")
mean_value = training["petal_length_cm"].mean()
training = training.fillna(value=mean_value)

# %%
def one_hot_encoding(df, feature):
    uniq_relations = list(df[feature].unique())
    # To get the same order of features in the prediction
    uniq_relations.sort()
    for unq in uniq_relations:
        df[unq] = np.where(df[feature] == unq, 1, 0)
    df = df.drop(feature, axis="columns")
    return df

# %%
X_train = training.loc[:, training.columns != "class"]

# %%
training["class"] = training["class"].astype(str)

# %%
for i in range(len(training["class"])):
    if training["class"][i] == "Iris-setossa":
        training["class"][i] = "Iris-setosa"
    elif training["class"][i] == "versicolor":
        training["class"][i] = "Iris-versicolor"
# Out:
# /tmp/ipykernel_12744/4088417815.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training["class"][i] = "Iris-setosa"
# /tmp/ipykernel_12744/4088417815.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training["class"][i] = "Iris-versicolor"

# %%
training = one_hot_encoding(training, "class")

# %%
setosa = training["Iris-setosa"]
versicolor = training["Iris-versicolor"]
virginica = training["Iris-virginica"]

# %%
X_train = X_train.loc[:, X_train.columns != "Iris-virginica"]
X_train = X_train.loc[:, X_train.columns != "Iris-setosa"]
X_train = X_train.loc[:, X_train.columns != "Iris-versicolor"]

# %%
X_train = np.array(X_train)

# %%
setosa_model = LogisticRegression(X_train, setosa)
versicolor_model = LogisticRegression(X_train, versicolor)
virginica_model = LogisticRegression(X_train, virginica)

# %%
setosa_model.train(epochs=1000)
versicolor_model.train(epochs=1000)
virginica_model.train(epochs=1000)
# Out:
# [+] Epochs: 0/1000 loss Function : 0.6592910287240047
# [+] Epochs: 100/1000 loss Function : 0.3325640120782675
# [+] Epochs: 200/1000 loss Function : 0.226046834777047
# [+] Epochs: 300/1000 loss Function : 0.17055088805320578
# [+] Epochs: 400/1000 loss Function : 0.13707920751205444
# [+] Epochs: 500/1000 loss Function : 0.11478250916338323
# [+] Epochs: 600/1000 loss Function : 0.09887364168623229
# [+] Epochs: 700/1000 loss Function : 0.08694638948586182
# [+] Epochs: 800/1000 loss Function : 0.07766626482971974
# [+] Epochs: 900/1000 loss Function : 0.07023530762143296
# [+] Epochs: 0/1000 loss Function : 0.6771436509615717
# [+] Epochs: 100/1000 loss Function : 0.5980720483933833
# [+] Epochs: 200/1000 loss Function : 0.5811472592708193
# [+] Epochs: 300/1000 loss Function : 0.5724599793152784
# [+] Epochs: 400/1000 loss Function : 0.567274857352729
# [+] Epochs: 500/1000 loss Function : 0.5637292716561975
# [+] Epochs: 600/1000 loss Function : 0.5610225435296173
# [+] Epochs: 700/1000 loss Function : 0.5587839654860202
# [+] Epochs: 800/1000 loss Function : 0.5568306567208129
# [+] Epochs: 900/1000 loss Function : 0.5550669548811283
# [+] Epochs: 0/1000 loss Function : 0.6862736146349308
# [+] Epochs: 100/1000 loss Function : 0.5331906555187137
# [+] Epochs: 200/1000 loss Function : 0.4711323724309392
# [+] Epochs: 300/1000 loss Function : 0.4365292153704804
# [+] Epochs: 400/1000 loss Function : 0.41367440628434154
# [+] Epochs: 500/1000 loss Function : 0.39680316928379605
# [+] Epochs: 600/1000 loss Function : 0.3834043862383016
# [+] Epochs: 700/1000 loss Function : 0.37223025067026916
# [+] Epochs: 800/1000 loss Function : 0.3625946102971019
# [+] Epochs: 900/1000 loss Function : 0.3540885401503626
# (array([-0.18679196, -1.11927774,  0.82535493,  0.5191369 ]),
#  -0.4454412793452172)

# %%
setosa_pred = setosa_model.predict(X_train)

# %%
setosa_model.zdo_acc(setosa, setosa_pred)
# Out:
# 0.9395571603043671

# %%
best_setosa_w, best_setosa_b = setosa_model.best_acc(X_train, setosa)
best_versicolor_w, best_versicolor_b = versicolor_model.best_acc(X_train, versicolor)
best_virginica_w, best_virginica_b = virginica_model.best_acc(X_train, virginica)
# Out:
# [*] Trying learning rate: 0.0001, lambda: 0.01, epochs: 10
#
# [+] Accuracy: 50.18062136496627%
#
# [*] Trying learning rate: 0.0001, lambda: 0.01, epochs: 100
#
# [+] Accuracy: 51.69573754877212%
#
# [*] Trying learning rate: 0.0001, lambda: 0.01, epochs: 1000
#
# [+] Accuracy: 59.59915103763001%
#
# [*] Trying learning rate: 0.0001, lambda: 0.01, epochs: 10000
#
# [+] Accuracy: 73.13209433560881%
#
# [*] Trying learning rate: 0.0001, lambda: 0.1, epochs: 10
#
# [+] Accuracy: 50.18062131662806%
#
# [*] Trying learning rate: 0.0001, lambda: 0.1, epochs: 100
#
# [+] Accuracy: 51.695732680780004%
#
# [*] Trying learning rate: 0.0001, lambda: 0.1, epochs: 1000
#
# [+] Accuracy: 59.59894839275444%
#
# [*] Trying learning rate: 0.0001, lambda: 0.1, epochs: 10000
#
# [+] Accuracy: 73.12841861254553%
#
# [*] Trying learning rate: 0.0001, lambda: 1.0, epochs: 10
#
# [+] Accuracy: 50.18062083324699%
#
# [*] Trying learning rate: 0.0001, lambda: 1.0, epochs: 100
#
# [+] Accuracy: 51.69568400188701%
#
# [*] Trying learning rate: 0.0001, lambda: 1.0, epochs: 1000
#
# [+] Accuracy: 59.596922245042116%
#
# [*] Trying learning rate: 0.0001, lambda: 1.0, epochs: 10000
#
# [+] Accuracy: 73.09172003087883%
#
# [*] Trying learning rate: 0.0001, lambda: 10.0, epochs: 10
#
# [+] Accuracy: 50.180615999521216%
#
# [*] Trying learning rate: 0.0001, lambda: 10.0, epochs: 100
#
# [+] Accuracy: 51.69519731575063%
#
# [*] Trying learning rate: 0.0001, lambda: 10.0, epochs: 1000
#
# [+] Accuracy: 59.576690855845584%
#
# [*] Trying learning rate: 0.0001, lambda: 10.0, epochs: 10000
#
# [+] Accuracy: 72.7305506502591%
#
# [*] Trying learning rate: 0.001, lambda: 0.01, epochs: 10
#
# [+] Accuracy: 51.705399293573315%
#
# [*] Trying learning rate: 0.001, lambda: 0.01, epochs: 100
#
# [+] Accuracy: 59.61886053145238%
#
# [*] Trying learning rate: 0.001, lambda: 0.01, epochs: 1000
#
# [+] Accuracy: 73.13420793658976%
#
# [*] Trying learning rate: 0.001, lambda: 0.01, epochs: 10000
#
# [+] Accuracy: 93.94743354537262%
#
# [*] Trying learning rate: 0.001, lambda: 0.1, epochs: 10
#
# [+] Accuracy: 51.7053947985862%
#
# [*] Trying learning rate: 0.001, lambda: 0.1, epochs: 100
#
# [+] Accuracy: 59.61865820193506%
#
# [*] Trying learning rate: 0.001, lambda: 0.1, epochs: 1000
#
# [+] Accuracy: 73.13053375621618%
#
# [*] Trying learning rate: 0.001, lambda: 0.1, epochs: 10000
#
# [+] Accuracy: 93.91495043141464%
#
# [*] Trying learning rate: 0.001, lambda: 1.0, epochs: 10
#
# [+] Accuracy: 51.70534984949741%
#
# [*] Trying learning rate: 0.001, lambda: 1.0, epochs: 100
#
# [+] Accuracy: 59.616635202220905%
#
# [*] Trying learning rate: 0.001, lambda: 1.0, epochs: 1000
#
# [+] Accuracy: 73.09385046966895%
#
# [*] Trying learning rate: 0.001, lambda: 1.0, epochs: 10000
#
# [+] Accuracy: 93.58931168108909%
#
# [*] Trying learning rate: 0.001, lambda: 10.0, epochs: 10
#
# [+] Accuracy: 51.70490043684273%
#
# [*] Trying learning rate: 0.001, lambda: 10.0, epochs: 100
#
# [+] Accuracy: 59.59643473640646%
#
# [*] Trying learning rate: 0.001, lambda: 10.0, epochs: 1000
#
# [+] Accuracy: 72.73282124541876%
#
# [*] Trying learning rate: 0.001, lambda: 10.0, epochs: 10000
#
# [+] Accuracy: 90.37811124948622%
#
# [*] Trying learning rate: 0.01, lambda: 0.01, epochs: 10
#
# [+] Accuracy: 59.823432673264534%
#
# [*] Trying learning rate: 0.01, lambda: 0.01, epochs: 100
#
# [+] Accuracy: 73.15541188540472%
#
# [*] Trying learning rate: 0.01, lambda: 0.01, epochs: 1000
#
# [+] Accuracy: 93.9521082939842%
#
# [*] Trying learning rate: 0.01, lambda: 0.01, epochs: 10000
#
# [+] Accuracy: 99.16915953677955%
#
# [*] Trying learning rate: 0.01, lambda: 0.1, epochs: 10
#
# [+] Accuracy: 59.823233472722805%
#
# [*] Trying learning rate: 0.01, lambda: 0.1, epochs: 100
#
# [+] Accuracy: 73.151753206094%
#
# [*] Trying learning rate: 0.01, lambda: 0.1, epochs: 1000
#
# [+] Accuracy: 93.919628791534%
#
# [*] Trying learning rate: 0.01, lambda: 0.1, epochs: 10000
#
# [+] Accuracy: 99.08305309432475%
#
# [*] Trying learning rate: 0.01, lambda: 1.0, epochs: 10
#
# [+] Accuracy: 59.82124170532459%
#
# [*] Trying learning rate: 0.01, lambda: 1.0, epochs: 100
#
# [+] Accuracy: 73.11522361279681%
#
# [*] Trying learning rate: 0.01, lambda: 1.0, epochs: 1000
#
# [+] Accuracy: 93.5940135710519%
#
# [*] Trying learning rate: 0.01, lambda: 1.0, epochs: 10000
#
# [+] Accuracy: 98.13147053413712%
#
# [*] Trying learning rate: 0.01, lambda: 10.0, epochs: 10
#
# [+] Accuracy: 59.80134783643989%
#
# [*] Trying learning rate: 0.01, lambda: 10.0, epochs: 100
#
# [+] Accuracy: 72.75560338410946%
#
# [*] Trying learning rate: 0.01, lambda: 10.0, epochs: 1000
#
# [+] Accuracy: 90.38212476960193%
#
# [*] Trying learning rate: 0.01, lambda: 10.0, epochs: 10000
#
# [+] Accuracy: 91.91342025587966%
#
# [*] Trying learning rate: 0.1, lambda: 0.01, epochs: 10
#
# [+] Accuracy: 73.39015752289741%
#
# [*] Trying learning rate: 0.1, lambda: 0.01, epochs: 100
#
# [+] Accuracy: 93.99985911656835%
#
# [*] Trying learning rate: 0.1, lambda: 0.01, epochs: 1000
#
# [+] Accuracy: 99.17051589246054%
#
# [*] Trying learning rate: 0.1, lambda: 0.01, epochs: 10000
#
# [+] Accuracy: 99.87018671500768%
#
# [*] Trying learning rate: 0.1, lambda: 0.1, epochs: 10
#
# [+] Accuracy: 73.38665496578682%
#
# [*] Trying learning rate: 0.1, lambda: 0.1, epochs: 100
#
# [+] Accuracy: 93.96741229544881%
#
# [*] Trying learning rate: 0.1, lambda: 0.1, epochs: 1000
#
# [+] Accuracy: 99.0843975747404%
#
# [*] Trying learning rate: 0.1, lambda: 0.1, epochs: 10000
#
# [+] Accuracy: 99.67360162001549%
#
# [*] Trying learning rate: 0.1, lambda: 1.0, epochs: 10
#
# [+] Accuracy: 73.35167359883503%
#
# [*] Trying learning rate: 0.1, lambda: 1.0, epochs: 100
#
# [+] Accuracy: 93.64199591421907%
#
# [*] Trying learning rate: 0.1, lambda: 1.0, epochs: 1000
#
# [+] Accuracy: 98.13226933225785%
#
# [*] Trying learning rate: 0.1, lambda: 1.0, epochs: 10000
#
# [+] Accuracy: 98.2791115690208%
#
# [*] Trying learning rate: 0.1, lambda: 10.0, epochs: 10
#
# [+] Accuracy: 73.00626906769196%
#
# [*] Trying learning rate: 0.1, lambda: 10.0, epochs: 100
#
# [+] Accuracy: 90.42272916142065%
#
# [*] Trying learning rate: 0.1, lambda: 10.0, epochs: 1000
#
# [+] Accuracy: 91.91348295212988%
#
# [*] Trying learning rate: 0.1, lambda: 10.0, epochs: 10000
#
# [+] Accuracy: 92.4827534532777%
#
#
# [*] Best accuracy : 0.9987018671500768 with w: [ 0.81097406  2.7955603  -4.83296261 -0.19980413] and b: 0.5256009726172104
#
# [*] Trying learning rate: 0.0001, lambda: 0.01, epochs: 10
#
# [+] Accuracy: 50.08579172399998%
#
# [*] Trying learning rate: 0.0001, lambda: 0.01, epochs: 100
#
# [+] Accuracy: 50.803130017062315%
#
# [*] Trying learning rate: 0.0001, lambda: 0.01, epochs: 1000
#
# [+] Accuracy: 54.503092231524455%
#
# [*] Trying learning rate: 0.0001, lambda: 0.01, epochs: 10000
#
# [+] Accuracy: 57.60816970895905%
#
# [*] Trying learning rate: 0.0001, lambda: 0.1, epochs: 10
#
# [+] Accuracy: 50.08579170123717%
#
# [*] Trying learning rate: 0.0001, lambda: 0.1, epochs: 100
#
# [+] Accuracy: 50.803127728447436%
#
# [*] Trying learning rate: 0.0001, lambda: 0.1, epochs: 1000
#
# [+] Accuracy: 54.50299301567541%
#
# [*] Trying learning rate: 0.0001, lambda: 0.1, epochs: 10000
#
# [+] Accuracy: 57.60741984639155%
#
# [*] Trying learning rate: 0.0001, lambda: 1.0, epochs: 10
#
# [+] Accuracy: 50.0857914736094%
#
# [*] Trying learning rate: 0.0001, lambda: 1.0, epochs: 100
#
# [+] Accuracy: 50.80310484278508%
#
# [*] Trying learning rate: 0.0001, lambda: 1.0, epochs: 1000
#
# [+] Accuracy: 54.50200103643916%
#
# [*] Trying learning rate: 0.0001, lambda: 1.0, epochs: 10000
#
# [+] Accuracy: 57.599931652130884%
#
# [*] Trying learning rate: 0.0001, lambda: 10.0, epochs: 10
#
# [+] Accuracy: 50.08578919737155%
#
# [*] Trying learning rate: 0.0001, lambda: 10.0, epochs: 100
#
# [+] Accuracy: 50.8028760348036%
#
# [*] Trying learning rate: 0.0001, lambda: 10.0, epochs: 1000
#
# [+] Accuracy: 54.492099146128915%
#
# [*] Trying learning rate: 0.0001, lambda: 10.0, epochs: 10000
#
# [+] Accuracy: 57.526083207510716%
#
# [*] Trying learning rate: 0.001, lambda: 0.01, epochs: 10
#
# [+] Accuracy: 50.80807279900146%
#
# [*] Trying learning rate: 0.001, lambda: 0.01, epochs: 100
#
# [+] Accuracy: 54.514911653200684%
#
# [*] Trying learning rate: 0.001, lambda: 0.01, epochs: 1000
#
# [+] Accuracy: 57.60847256913387%
#
# [*] Trying learning rate: 0.001, lambda: 0.01, epochs: 10000
#
# [+] Accuracy: 61.11440919748156%
#
# [*] Trying learning rate: 0.001, lambda: 0.1, epochs: 10
#
# [+] Accuracy: 50.80807068289551%
#
# [*] Trying learning rate: 0.001, lambda: 0.1, epochs: 100
#
# [+] Accuracy: 54.514812322634995%
#
# [*] Trying learning rate: 0.001, lambda: 0.1, epochs: 1000
# [+] Accuracy: 57.60772297070669%
#
# [*] Trying learning rate: 0.001, lambda: 0.1, epochs: 10000
#
# [+] Accuracy: 61.10759227564149%
#
# [*] Trying learning rate: 0.001, lambda: 1.0, epochs: 10
#
# [+] Accuracy: 50.8080495222071%
#
# [*] Trying learning rate: 0.001, lambda: 1.0, epochs: 100
#
# [+] Accuracy: 54.5138191946398%
#
# [*] Trying learning rate: 0.001, lambda: 1.0, epochs: 1000
#
# [+] Accuracy: 57.60023739672355%
#
# [*] Trying learning rate: 0.001, lambda: 1.0, epochs: 10000
#
# [+] Accuracy: 61.04001288372965%
#
# [*] Trying learning rate: 0.001, lambda: 10.0, epochs: 10
#
# [+] Accuracy: 50.80783795246013%
#
# [*] Trying learning rate: 0.001, lambda: 10.0, epochs: 100
#
# [+] Accuracy: 54.5039056582308%
#
# [*] Trying learning rate: 0.001, lambda: 10.0, epochs: 1000
#
# [+] Accuracy: 57.52641310396085%
#
# [*] Trying learning rate: 0.001, lambda: 10.0, epochs: 10000
#
# [+] Accuracy: 60.423778284374585%
#
# [*] Trying learning rate: 0.01, lambda: 0.01, epochs: 10
#
# [+] Accuracy: 54.638235990150505%
#
# [*] Trying learning rate: 0.01, lambda: 0.01, epochs: 100
#
# [+] Accuracy: 57.61150338618728%
#
# [*] Trying learning rate: 0.01, lambda: 0.01, epochs: 1000
#
# [+] Accuracy: 61.11500526789941%
#
# [*] Trying learning rate: 0.01, lambda: 0.01, epochs: 10000
#
# [+] Accuracy: 64.66682282901868%
#
# [*] Trying learning rate: 0.01, lambda: 0.1, epochs: 10
#
# [+] Accuracy: 54.63813539034812%
#
# [*] Trying learning rate: 0.01, lambda: 0.1, epochs: 100
#
# [+] Accuracy: 57.61075644520128%
#
# [*] Trying learning rate: 0.01, lambda: 0.1, epochs: 1000
#
# [+] Accuracy: 61.108188156393105%
#
# [*] Trying learning rate: 0.01, lambda: 0.1, epochs: 10000
#
# [+] Accuracy: 64.58401996256417%
#
# [*] Trying learning rate: 0.01, lambda: 1.0, epochs: 10
#
# [+] Accuracy: 54.637129552507744%
#
# [*] Trying learning rate: 0.01, lambda: 1.0, epochs: 100
#
# [+] Accuracy: 57.60329723432689%
#
# [*] Trying learning rate: 0.01, lambda: 1.0, epochs: 1000
#
# [+] Accuracy: 61.04060572480169%
#
# [*] Trying learning rate: 0.01, lambda: 1.0, epochs: 10000
#
# [+] Accuracy: 63.87987287846516%
#
# [*] Trying learning rate: 0.01, lambda: 10.0, epochs: 10
#
# [+] Accuracy: 54.62708717771913%
#
# [*] Trying learning rate: 0.01, lambda: 10.0, epochs: 100
#
# [+] Accuracy: 57.529716055050606%
#
# [*] Trying learning rate: 0.01, lambda: 10.0, epochs: 1000
#
# [+] Accuracy: 60.42427052079991%
#
# [*] Trying learning rate: 0.01, lambda: 10.0, epochs: 10000
#
# [+] Accuracy: 61.36470735168626%
#
# [*] Trying learning rate: 0.1, lambda: 0.01, epochs: 10
#
# [+] Accuracy: 57.6404552129829%
#
# [*] Trying learning rate: 0.1, lambda: 0.01, epochs: 100
#
# [+] Accuracy: 61.12091795135586%
#
# [*] Trying learning rate: 0.1, lambda: 0.01, epochs: 1000
#
# [+] Accuracy: 64.66809595602498%
#
# [*] Trying learning rate: 0.1, lambda: 0.01, epochs: 10000
#
# [+] Accuracy: 68.71109738374446%
#
# [*] Trying learning rate: 0.1, lambda: 0.1, epochs: 10
#
# [+] Accuracy: 57.639736828810996%
#
# [*] Trying learning rate: 0.1, lambda: 0.1, epochs: 100
#
# [+] Accuracy: 61.114098913987036%
#
# [*] Trying learning rate: 0.1, lambda: 0.1, epochs: 1000
#
# [+] Accuracy: 64.58526856650917%
#
# [*] Trying learning rate: 0.1, lambda: 0.1, epochs: 10000
#
# [+] Accuracy: 68.38909855488015%
#
# [*] Trying learning rate: 0.1, lambda: 1.0, epochs: 10
#
# [+] Accuracy: 57.63256104991106%
#
# [*] Trying learning rate: 0.1, lambda: 1.0, epochs: 100
#
# [+] Accuracy: 61.046485802301945%
#
# [*] Trying learning rate: 0.1, lambda: 1.0, epochs: 1000
#
# [+] Accuracy: 63.88082074245865%
#
# [*] Trying learning rate: 0.1, lambda: 1.0, epochs: 10000
#
# [+] Accuracy: 66.57015138879271%
#
# [*] Trying learning rate: 0.1, lambda: 10.0, epochs: 10
#
# [+] Accuracy: 57.561605781517045%
#
# [*] Trying learning rate: 0.1, lambda: 10.0, epochs: 100
#
# [+] Accuracy: 60.42914271504556%
#
# [*] Trying learning rate: 0.1, lambda: 10.0, epochs: 1000
#
# [+] Accuracy: 61.36482978196026%
#
# [*] Trying learning rate: 0.1, lambda: 10.0, epochs: 10000
#
# [+] Accuracy: 62.20603614973486%
#
#
# [*] Best accuracy : 0.6871109738374446 with w: [-0.43621041 -2.04801294  1.51623705 -3.01629679] and b: 5.753364089937267
#
# [*] Trying learning rate: 0.0001, lambda: 0.01, epochs: 10
#
# [+] Accuracy: 50.036136261342136%
#
# [*] Trying learning rate: 0.0001, lambda: 0.01, epochs: 100
#
# [+] Accuracy: 50.34473174885639%
#
# [*] Trying learning rate: 0.0001, lambda: 0.01, epochs: 1000
#
# [+] Accuracy: 52.363969647404616%
#
# [*] Trying learning rate: 0.0001, lambda: 0.01, epochs: 10000
#
# [+] Accuracy: 59.72361288797388%
#
# [*] Trying learning rate: 0.0001, lambda: 0.1, epochs: 10
#
# [+] Accuracy: 50.03613625196741%
#
# [*] Trying learning rate: 0.0001, lambda: 0.1, epochs: 100
#
# [+] Accuracy: 50.34473078139812%
#
# [*] Trying learning rate: 0.0001, lambda: 0.1, epochs: 1000
#
# [+] Accuracy: 52.363911899242844%
#
# [*] Trying learning rate: 0.0001, lambda: 0.1, epochs: 10000
#
# [+] Accuracy: 59.72162470968203%
#
# [*] Trying learning rate: 0.0001, lambda: 1.0, epochs: 10
#
# [+] Accuracy: 50.0361361582206%
#
# [*] Trying learning rate: 0.0001, lambda: 1.0, epochs: 100
#
# [+] Accuracy: 50.34472110702261%
#
# [*] Trying learning rate: 0.0001, lambda: 1.0, epochs: 1000
#
# [+] Accuracy: 52.363334533337195%
#
# [*] Trying learning rate: 0.0001, lambda: 1.0, epochs: 10000
#
# [+] Accuracy: 59.70177673972259%
#
# [*] Trying learning rate: 0.0001, lambda: 10.0, epochs: 10
#
# [+] Accuracy: 50.03613522076922%
#
# [*] Trying learning rate: 0.0001, lambda: 10.0, epochs: 100
#
# [+] Accuracy: 50.3446243839613%
#
# [*] Trying learning rate: 0.0001, lambda: 10.0, epochs: 1000
#
# [+] Accuracy: 52.35757242817984%
#
# [*] Trying learning rate: 0.0001, lambda: 10.0, epochs: 10000
#
# [+] Accuracy: 59.50664702566431%
#
# [*] Trying learning rate: 0.001, lambda: 0.01, epochs: 10
#
# [+] Accuracy: 50.346252271091466%
#
# [*] Trying learning rate: 0.001, lambda: 0.01, epochs: 100
#
# [+] Accuracy: 52.3679254414251%
#
# [*] Trying learning rate: 0.001, lambda: 0.01, epochs: 1000
#
# [+] Accuracy: 59.724817917845265%
#
# [*] Trying learning rate: 0.001, lambda: 0.01, epochs: 10000
#
# [+] Accuracy: 73.24769438848429%
#
# [*] Trying learning rate: 0.001, lambda: 0.1, epochs: 10
#
# [+] Accuracy: 50.346251380784025%
#
# [*] Trying learning rate: 0.001, lambda: 0.1, epochs: 100
#
# [+] Accuracy: 52.367867876583716%
#
# [*] Trying learning rate: 0.001, lambda: 0.1, epochs: 1000
#
# [+] Accuracy: 59.72283064487489%
#
# [*] Trying learning rate: 0.001, lambda: 0.1, epochs: 10000
#
# [+] Accuracy: 73.22332394232845%
#
# [*] Trying learning rate: 0.001, lambda: 1.0, epochs: 10
#
# [+] Accuracy: 50.34624247786654%
#
# [*] Trying learning rate: 0.001, lambda: 1.0, epochs: 100
#
# [+] Accuracy: 52.36729234192986%
#
# [*] Trying learning rate: 0.001, lambda: 1.0, epochs: 1000
#
# [+] Accuracy: 59.702991652867354%
#
# [*] Trying learning rate: 0.001, lambda: 1.0, epochs: 10000
#
# [+] Accuracy: 72.98209037416241%
#
# [*] Trying learning rate: 0.001, lambda: 10.0, epochs: 10
#
# [+] Accuracy: 50.34615346436843%
#
# [*] Trying learning rate: 0.001, lambda: 10.0, epochs: 100
#
# [+] Accuracy: 52.361548354729024%
#
# [*] Trying learning rate: 0.001, lambda: 10.0, epochs: 1000
#
# [+] Accuracy: 59.50794440982696%
#
# [*] Trying learning rate: 0.001, lambda: 10.0, epochs: 10000
#
# [+] Accuracy: 70.8085460685274%
#
# [*] Trying learning rate: 0.01, lambda: 0.01, epochs: 10
#
# [+] Accuracy: 52.40917687013782%
#
# [*] Trying learning rate: 0.01, lambda: 0.01, epochs: 100
#
# [+] Accuracy: 59.73689637399184%
#
# [*] Trying learning rate: 0.01, lambda: 0.01, epochs: 1000
#
# [+] Accuracy: 73.25108238518354%
#
# [*] Trying learning rate: 0.01, lambda: 0.01, epochs: 10000
#
# [+] Accuracy: 85.73703745335764%
#
# [*] Trying learning rate: 0.01, lambda: 0.1, epochs: 10
#
# [+] Accuracy: 52.40912109555704%
#
# [*] Trying learning rate: 0.01, lambda: 0.1, epochs: 100
#
# [+] Accuracy: 59.734918201914525%
#
# [*] Trying learning rate: 0.01, lambda: 0.1, epochs: 1000
#
# [+] Accuracy: 73.22671010239492%
#
# [*] Trying learning rate: 0.01, lambda: 0.1, epochs: 10000
#
# [+] Accuracy: 85.4984421561428%
#
# [*] Trying learning rate: 0.01, lambda: 1.0, epochs: 10
#
# [+] Accuracy: 52.408563444527005%
#
# [*] Trying learning rate: 0.01, lambda: 1.0, epochs: 100
#
# [+] Accuracy: 59.715169466312545%
#
# [*] Trying learning rate: 0.01, lambda: 1.0, epochs: 1000
#
# [+] Accuracy: 72.98545269709345%
#
# [*] Trying learning rate: 0.01, lambda: 1.0, epochs: 10000
#
# [+] Accuracy: 83.3401020927256%
#
# [*] Trying learning rate: 0.01, lambda: 10.0, epochs: 10
#
# [+] Accuracy: 52.40299640164127%
#
# [*] Trying learning rate: 0.01, lambda: 10.0, epochs: 100
#
# [+] Accuracy: 59.520951697038086%
#
# [*] Trying learning rate: 0.01, lambda: 10.0, epochs: 1000
# [+] Accuracy: 70.81129072649092%
#
# [*] Trying learning rate: 0.01, lambda: 10.0, epochs: 10000
#
# [+] Accuracy: 75.78628413362351%
#
# [*] Trying learning rate: 0.1, lambda: 0.01, epochs: 10
#
# [+] Accuracy: 59.859755004423775%
#
# [*] Trying learning rate: 0.1, lambda: 0.01, epochs: 100
#
# [+] Accuracy: 73.28507067908554%
#
# [*] Trying learning rate: 0.1, lambda: 0.01, epochs: 1000
#
# [+] Accuracy: 85.74238145017125%
#
# [*] Trying learning rate: 0.1, lambda: 0.01, epochs: 10000
#
# [+] Accuracy: 93.13315850643771%
#
# [*] Trying learning rate: 0.1, lambda: 0.1, epochs: 10
#
# [+] Accuracy: 59.85787236012106%
#
# [*] Trying learning rate: 0.1, lambda: 0.1, epochs: 100
#
# [+] Accuracy: 73.26067909438542%
#
# [*] Trying learning rate: 0.1, lambda: 0.1, epochs: 1000
#
# [+] Accuracy: 85.50368811180807%
#
# [*] Trying learning rate: 0.1, lambda: 0.1, epochs: 10000
#
# [+] Accuracy: 92.40939584912061%
#
# [*] Trying learning rate: 0.1, lambda: 1.0, epochs: 10
#
# [+] Accuracy: 59.83907135977988%
#
# [*] Trying learning rate: 0.1, lambda: 1.0, epochs: 100
#
# [+] Accuracy: 73.01917376514324%
#
# [*] Trying learning rate: 0.1, lambda: 1.0, epochs: 1000
#
# [+] Accuracy: 83.34403032321813%
#
# [*] Trying learning rate: 0.1, lambda: 1.0, epochs: 10000
#
# [+] Accuracy: 88.76563284830962%
#
# [*] Trying learning rate: 0.1, lambda: 10.0, epochs: 10
#
# [+] Accuracy: 59.653595231063015%
#
# [*] Trying learning rate: 0.1, lambda: 10.0, epochs: 100
#
# [+] Accuracy: 70.83871817438822%
#
# [*] Trying learning rate: 0.1, lambda: 10.0, epochs: 1000
#
# [+] Accuracy: 75.78704495454258%
#
# [*] Trying learning rate: 0.1, lambda: 10.0, epochs: 10000
#
# [+] Accuracy: 81.66317489699173%
#
#
# [*] Best accuracy : 0.9313315850643771 with w: [ 0.01479489 -6.08551791  3.50283602  5.17281607] and b: -8.37155840957538

# %%
best_setosa_pred = setosa_model.predict(X_train, best_setosa_w, best_setosa_b)
best_versicolor_pred = versicolor_model.predict(X_train, best_versicolor_w, best_versicolor_b)
best_virginica_pred = virginica_model.predict(X_train, best_virginica_w, best_virginica_b)

# %%
setosa_model.zdo_acc(setosa, best_setosa_pred)
# Out:
# 0.9987018671500768

# %%
versicolor_model.zdo_acc(versicolor, best_versicolor_pred)
# Out:
# 0.6871109738374446

# %%
virginica_model.zdo_acc(virginica, best_virginica_pred)
# Out:
# 0.9313315850643771
